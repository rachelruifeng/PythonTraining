# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df = pd.read_csv('train.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot(x='Sex', kind='count', data=titanic_df)

# %%
sns.factorplot(x='Sex', kind='count', data=titanic_df, hue='Pclass')

# %%
sns.factorplot(x='Pclass', kind='count', data=titanic_df, hue='Sex')

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['person'] = titanic_df[['Age','Sex']].apply(male_female_child, axis=1)

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.factorplot(x='Pclass', kind='count', data=titanic_df, hue='person', )

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
# aspect is to change the width of the figure
fig = sns.FacetGrid(titanic_df, hue='Sex', aspect=4)
# shade = False will draw two lines
fig.map(sns.kdeplot, 'Age', shade=True)

oldest = titanic_df['Age'].max()
# x limit is from 0 to oldest
fig.set(xlim = (0, oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='person', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim = (0, oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='Pclass', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim = (0, oldest))
fig.add_legend()

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []
for level in deck:
    levels.append(level[0])
    
cabin_df = DataFrame(levels)

# %%
cabin_df.columns = ['Cabin']

# %%
sns.factorplot(data=cabin_df, x='Cabin', kind='count', palette='winter_d')

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']
sns.factorplot(data=cabin_df, x='Cabin', kind='count', palette='winter_d')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
sns.factorplot(data=titanic_df, 
               x='Embarked',
               hue='Pclass',
               order=['C','Q','S'], 
               kind='count')

# %%
titanic_df['Alone'] = titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df.Alone > 0] = 'With Family'
titanic_df['Alone'].loc[titanic_df.Alone == 0] = 'Alone'
# Out:
# C:\Users\z3520413\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(x='Alone', data=titanic_df, kind = 'count', palette='Blues')

# %%
titanic_df['Survivor'] = titanic_df['Survived'].map({0:'no',1:'yes'})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(x='Survivor', data=titanic_df, kind='count', palette='Set1')

# %%
sns.factorplot(x='Pclass', y='Survived', data=titanic_df)

# %%
sns.factorplot(x='Pclass', y='Survived', hue='person', data=titanic_df)

# %%
sns.lmplot(x='Age', y='Survived', data=titanic_df)

# %%
sns.lmplot(x='Age', y='Survived', hue='Pclass', data=titanic_df, palette='winter')

# %%
generations = [10,20,40,60,80]

sns.lmplot(x='Age',
           y='Survived',
           data=titanic_df, 
           hue='Pclass', 
           palette='winter',
           x_bins=generations)

# %%
sns.lmplot(x='Age',
           y='Survived',
           data=titanic_df, 
           hue='Sex', 
           palette='winter',
           x_bins=generations)

# %% [markdown]
# 1) Did the deck have an effect on the passenger survival rate? Did this answer match up with your intuition?

# %% [markdown]
# 2) Did having a family member increase the odds of surviving the crash?

# %%
titanic_df.Cabin
# Out:
# 0              NaN
# 1              C85
# 2              NaN
# 3             C123
# 4              NaN
# 5              NaN
# 6              E46
# 7              NaN
# 8              NaN
# 9              NaN
# 10              G6
# 11            C103
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             D56
# 22             NaN
# 23              A6
# 24             NaN
# 25             NaN
# 26             NaN
# 27     C23 C25 C27
# 28             NaN
# 29             NaN
#           ...
# 861            NaN
# 862            D17
# 863            NaN
# 864            NaN
# 865            NaN
# 866            NaN
# 867            A24
# 868            NaN
# 869            NaN
# 870            NaN
# 871            D35
# 872    B51 B53 B55
# 873            NaN
# 874            NaN
# 875            NaN
# 876            NaN
# ...

# %%
titanic_df['Deck'] = titanic_df.Cabin.str[:1]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot(x='Deck', y='Survived', order=['A','B','C','D','E','F'], hue='Sex', data= titanic_df)

# %%
sns.factorplot(x='Alone', y='Survived', hue='Pclass', data = titanic_df)
